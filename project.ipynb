# %% [markdown]
# Project
#
# Reading data

# %%
import pandas as pd
dataset_day="./data/day.csv" #you must change this var whether the dataset is in another path
data=pd.read_csv(dataset_day)
print(data.head())
print(data.dtypes)
print(data.describe())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# instant         int64
# ...

# %%
dataset_hour="./data/hour.csv" #you must change this var whether the dataset is in another path
data=pd.read_csv(dataset_hour)
print(data.head())
print(data.dtypes)
print(data.describe())
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
# instant         int64
# dteday         object
# season          int64
# yr              int64
# ...

# %%
from river import stream
from rich import print
days = stream.iter_csv(dataset_day)
sample, target = next(days)
print(sample)
print(target)
# Out:
# {
#     'instant': '1',
#     'dteday': '2011-01-01',
#     'season': '1',
#     'yr': '0',
#     'mnth': '1',
#     'holiday': '0',
#     'weekday': '6',
#     'workingday': '0',
#     'weathersit': '2',
#     'temp': '0.344167',
#     'atemp': '0.363625',
#     'hum': '0.805833',
#     'windspeed': '0.160446',
#     'casual': '331',
#     'registered': '654',
#     'cnt': '985'
# }
# None

# %%
hours = stream.iter_csv(dataset_hour)
sample, target = next(hours)
print(sample)
print(target)
# Out:
# {
#     'instant': '1',
#     'dteday': '2011-01-01',
#     'season': '1',
#     'yr': '0',
#     'mnth': '1',
#     'hr': '0',
#     'holiday': '0',
#     'weekday': '6',
#     'workingday': '0',
#     'weathersit': '1',
#     'temp': '0.24',
#     'atemp': '0.2879',
#     'hum': '0.81',
#     'windspeed': '0',
#     'casual': '3',
#     'registered': '13',
#     'cnt': '16'
# }
# None
